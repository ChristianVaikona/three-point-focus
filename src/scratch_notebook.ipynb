# %%
import pandas as pd
import numpy as np
from nba_api.stats.endpoints import shotchartdetail, leagueleaders

# %%
leaders = leagueleaders.LeagueLeaders(
    season='2024-25',
    season_type_all_star='Regular Season',
    stat_category_abbreviation='FG3_PCT'  # sort by 3P%
)
df_leaders = leaders.get_data_frames()[0]

print(df_leaders.head(10))
# Out:
#    PLAYER_ID  RANK           PLAYER     TEAM_ID TEAM  GP   MIN  FGM   FGA  \
# 0     203552     1       Seth Curry  1610612766  CHA  68  1062  164   343
# 1     203897     2      Zach LaVine  1610612758  SAC  74  2603  625  1223
# 2    1627752     3   Taurean Prince  1610612749  MIL  80  2166  235   514
# 3    1629660     4        Ty Jerome  1610612739  CLE  70  1392  319   618
# 4    1630249     5       Vít Krejčí  1610612737  ATL  57  1153  145   292
# 5     201587     6    Nicolas Batum  1610612746  LAC  78  1367  104   238
# 6     203084     7  Harrison Barnes  1610612759  SAS  82  2230  347   683
# 7    1631165     8       Keon Ellis  1610612758  SAC  80  1948  227   464
# 8    1628379     9     Luke Kennard  1610612763  MEM  65  1472  206   431
# 9    1630174    10    Aaron Nesmith  1610612754  IND  45  1122  192   379
#
#    FG_PCT  ...  REB  AST  STL  BLK  TOV   PF   PTS   EFF  AST_TOV  STL_TOV
# 0   0.478  ...  113   60   27    7   32   59   444   434     1.88     0.84
# 1   0.511  ...  315  310   58   12  208  121  1724  1563     1.49     0.28
# 2   0.457  ...  287  155   76   15   82  165   656   819     1.89     0.93
# 3   0.516  ...  173  237   78    3   92  102   878   959     2.58     0.85
# 4   0.497  ...  156  147   36   26   50  105   412   567     2.94     0.72
# 5   0.437  ...  218   84   52   36   34  111   313   531     2.47     1.53
# 6   0.508  ...  310  136   39   14   50   75  1011  1086     2.72     0.78
# 7   0.489  ...  212  120  121   63   71  176   666   861     1.69     1.70
# 8   0.478  ...  183  215   50    5   72   59   576   726     2.99     0.69
# 9   0.507  ...  178   54   35   17   37  114   541   594     1.46     0.95
#
# [10 rows x 28 columns]

# %%
shots = shotchartdetail.ShotChartDetail(
    team_id=0,  # 0 = all teams for that player
    player_id=203552,
    season_nullable='2024-25',
    season_type_all_star='Regular Season',
    context_measure_simple='FGA'  # get all attempts
)

df_shots = shots.get_data_frames()[0]  # Shot_Chart_Detail table

print(df_shots.head(10))
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID PLAYER_NAME  \
# 0  Shot Chart Detail  0022400003            121     203552  Seth Curry
# 1  Shot Chart Detail  0022400022            103     203552  Seth Curry
# 2  Shot Chart Detail  0022400040            128     203552  Seth Curry
# 3  Shot Chart Detail  0022400040            145     203552  Seth Curry
# 4  Shot Chart Detail  0022400040            157     203552  Seth Curry
# 5  Shot Chart Detail  0022400040            160     203552  Seth Curry
# 6  Shot Chart Detail  0022400050            218     203552  Seth Curry
# 7  Shot Chart Detail  0022400068            150     203552  Seth Curry
# 8  Shot Chart Detail  0022400068            176     203552  Seth Curry
# 9  Shot Chart Detail  0022400068            188     203552  Seth Curry
#
#       TEAM_ID          TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0  1610612766  Charlotte Hornets       1                  3
# 1  1610612766  Charlotte Hornets       1                  3
# 2  1610612766  Charlotte Hornets       1                  0
# 3  1610612766  Charlotte Hornets       2                 11
# 4  1610612766  Charlotte Hornets       2                 10
# 5  1610612766  Charlotte Hornets       2                 10
# 6  1610612766  Charlotte Hornets       2                  7
# 7  1610612766  Charlotte Hornets       1                  2
# 8  1610612766  Charlotte Hornets       1                  0
# 9  1610612766  Charlotte Hornets       2                 11
#
#    SECONDS_REMAINING  ...         SHOT_ZONE_AREA SHOT_ZONE_RANGE  \
# 0                  1  ...  Right Side Center(RC)         24+ ft.
# 1                 45  ...          Right Side(R)         24+ ft.
# 2                  6  ...   Left Side Center(LC)       16-24 ft.
# 3                 43  ...   Left Side Center(LC)       16-24 ft.
# 4                 38  ...          Right Side(R)        8-16 ft.
# 5                 14  ...           Left Side(L)        8-16 ft.
# 6                  9  ...  Right Side Center(RC)         24+ ft.
# 7                  5  ...          Right Side(R)         24+ ft.
# 8                  1  ...          Right Side(R)        8-16 ft.
# 9                 47  ...           Left Side(L)         24+ ft.
#
#   SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  \
# 0            25   191   163                   1               0   20241112
# 1            23   235     6                   1               0   20241119
# 2            16  -105   132                   1               1   20241129
# 3            16   -62   155                   1               1   20241129
# 4            13    87    99                   1               1   20241129
# 5            11  -105    33                   1               0   20241129
# 6            26   211   152                   1               0   20241203
# 7            24   232    75                   1               1   20241023
# 8            14   140    10                   1               0   20241023
# 9            23  -238    21                   1               1   20241023
#
#    HTM  VTM
# 0  ORL  CHA
# 1  BKN  CHA
# 2  CHA  NYK
# 3  CHA  NYK
# 4  CHA  NYK
# 5  CHA  NYK
# 6  CHA  PHI
# 7  HOU  CHA
# 8  HOU  CHA
# 9  HOU  CHA
#
# [10 rows x 24 columns]
